# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
iris = load_iris()
dir(iris)
df = pd.DataFrame(iris.data,columns = ['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)'])

# %%
target = iris.target
df['target'] = target

# %%
x = df.drop(['target'],axis =1)
y = target

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state = 30)

# %%
x_train.shape,y_train.shape
# Out:
# ((120, 4), (120,))

# %%
model = LogisticRegression()
model = model.fit(x_train,y_train)
# Out:
# C:\Users\safda\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
predict = model.predict(x_test)

# %%
predict
# Out:
# array([0, 0, 0, 2, 1, 1, 2, 2, 1, 2, 0, 2, 1, 1, 0, 1, 0, 0, 0, 1, 2, 0,
#        0, 0, 2, 2, 2, 2, 0, 1])

# %%
model.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
import matplotlib.pyplot as plt
plt.plot(predict,x_test)
# Out:
# [<matplotlib.lines.Line2D at 0x29959acf9a0>,
#  <matplotlib.lines.Line2D at 0x29959acfa60>,
#  <matplotlib.lines.Line2D at 0x29959acfb80>,
#  <matplotlib.lines.Line2D at 0x29959acfca0>]
