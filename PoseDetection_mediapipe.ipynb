# %%
# !pip install mediapipe opencv-python
# Out:
# Requirement already satisfied: mediapipe in c:\users\safda\anaconda3\lib\site-packages (0.10.11)
# Requirement already satisfied: opencv-python in c:\users\safda\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\safda\anaconda3\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: opencv-contrib-python in c:\users\safda\anaconda3\lib\site-packages (from mediapipe) (4.9.0.80)
# Requirement already satisfied: matplotlib in c:\users\safda\anaconda3\lib\site-packages (from mediapipe) (3.5.2)
# Requirement already satisfied: absl-py in c:\users\safda\anaconda3\lib\site-packages (from mediapipe) (2.0.0)
# Requirement already satisfied: jax in c:\users\safda\anaconda3\lib\site-packages (from mediapipe) (0.4.26)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\safda\anaconda3\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\safda\anaconda3\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\safda\anaconda3\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: numpy in c:\users\safda\anaconda3\lib\site-packages (from mediapipe) (1.24.4)
# Requirement already satisfied: CFFI>=1.0 in c:\users\safda\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: scipy>=1.9 in c:\users\safda\anaconda3\lib\site-packages (from jax->mediapipe) (1.9.1)
# Requirement already satisfied: opt-einsum in c:\users\safda\anaconda3\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\safda\anaconda3\lib\site-packages (from jax->mediapipe) (0.2.0)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\safda\anaconda3\lib\site-packages (from jax->mediapipe) (4.11.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\safda\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\safda\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\safda\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\safda\anaconda3\lib\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\safda\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\safda\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\safda\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.2)
# Requirement already satisfied: pycparser in c:\users\safda\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: zipp>=0.5 in c:\users\safda\anaconda3\lib\site-packages (from importlib-metadata>=4.6->jax->mediapipe) (3.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\safda\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)

# %%
import cv2
import mediapipe as mp
import math
import numpy as np

mp_drawing=mp.solutions.drawing_utils   #for drawing visualizations on images or videos, often used for debugging or displaying results
mp_pose=mp.solutions.pose               #provides functionalities specifically designed for pose estimation


def analyse_posture(landmarks):
    """
    Classifies the movement based on the shoulder, hip and nose landmarks.

    Args:
        landmarks: A list of landmarks detected by the pose model.

    Returns:
        A string indicating the movement, "tilted right", "tilted left", "leaning forward" or "leaning backward".
    """

    left_shoulder = landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER]
    right_shoulder = landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER]
    left_hip = landmarks[mp_pose.PoseLandmark.LEFT_HIP]
    right_hip = landmarks[mp_pose.PoseLandmark.RIGHT_HIP]
    nose = landmarks[mp_pose.PoseLandmark.NOSE]
    posture = "straight"
    dist_nose_shoulder_left = math.sqrt((left_shoulder.x - nose.x)**2 + (left_shoulder.y - nose.y)**2)
    dist_nose_shoulder_right = math.sqrt((right_shoulder.x - nose.x)**2 + (right_shoulder.y - nose.y)**2)
    nose_shoulder_ratio = dist_nose_shoulder_left / dist_nose_shoulder_right
    shoulder_midpoint = np.average([left_shoulder.x, right_shoulder.x], axis=0)
    hip_midpoint = np.average([left_hip.x, right_hip.x], axis=0)

    if right_shoulder.y < right_hip.y:
        right_hip_angle = math.degrees(math.atan((right_hip.y - right_shoulder.y) / (right_shoulder.x - right_hip.x)))
    else:
        right_hip_angle = math.degrees(
            math.atan((right_hip.y - right_shoulder.y) / (right_shoulder.x - right_hip.x)) + math.pi
        )

    if right_shoulder.y < nose.y:
        nose_angle = math.degrees(math.atan((nose.y - right_shoulder.y) / (right_shoulder.x - nose.x)))
    else:
        nose_angle = math.degrees(math.atan((nose.y - right_shoulder.y) / (right_shoulder.x - nose.x)) + math.pi)

    if (right_hip_angle - nose_angle) >= 90 or (right_hip_angle - nose_angle) <= -90:
        if nose_shoulder_ratio > 1.15:
            posture='right'
            print(nose_shoulder_ratio,posture)
        elif nose_shoulder_ratio < 0.85:
            posture = 'left'
            print(nose_shoulder_ratio,posture)
        elif nose_shoulder_ratio > 0.85 and nose_shoulder_ratio < 1.15:
            posture = 'straight'
            print(nose_shoulder_ratio,posture)
        else:
            pass
        # if nose.x < (shoulder_midpoint+20 ) and nose.x > (shoulder_midpoint-20):
        #     posture= "straight"
        # if nose.x > (shoulder_midpoint+20) :
        #     posture= "tilted left"
            
        # elif nose.x < (shoulder_midpoint-20) :
        #     posture="tilted right"
            
    elif nose.y > shoulder_midpoint-30:
        posture= "leaning forward"
        print(nose_shoulder_ratio,posture)
        
    else:
        pass
    
    return posture



   

cap = cv2.VideoCapture(0)
with mp_pose.Pose(min_detection_confidence=0.5,min_tracking_confidence=0.5) as pose:    #setup Mediapipe instance
    while cap.isOpened():
        ret,frame=cap.read()
        if not ret:
            print("Error: Failed to read frame from video capture")
            break
        img=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
        img.flags.writeable = False        # Sets the image flag to read-only (temporary). This might be done for internal processing within MediaPipe to avoid unintended modifications.
        results = pose.process(img)
        img.flags.writeable = True
        img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
        # extracting the joint landmarks
        try:
            landmarks=results.pose_landmarks.landmark
            posture = analyse_posture(landmarks)
#             print(f"Detected Posture: {posture}")
            cv2.putText(img, posture, (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
#             shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
#             elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
#             wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
#             print(landmarks)
        except:
            pass
        
        mp_drawing.draw_landmarks(img,results.pose_landmarks,mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(245,117,66),thickness=2,circle_radius=2),
                                 mp_drawing.DrawingSpec(color=(245,66,230),thickness=2,circle_radius=2)
                                 )
        cv2.imshow('MediaPipe Feed', img)

        if cv2.waitKey(25) & 0xff == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()


# for lndmrk in mp_pose.PoseLandmark:
#     print(lndmrk)

# print(landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value] )  # landmarks full position
